# %%
# %pip install ultralytics
# %pip install roboflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="Zfui3NyvlYAU1l7uvSpU")
project = rf.workspace("university-bswxt").project("crack-bphdr")
dataset = project.version(2).download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.109, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to crack-2 in yolov8:: 100%|██████████| 8070/8070 [00:02<00:00, 3206.37it/s]

# %%
from filtro_teste import filter 


test_images_path = './crack-2/test/images'
train_images_path = './crack-2/train/images'
filter(test_images_path)
# Out:
# ./crack-2/test/images/1616.rf.c868709931a671796794fdbb95352c5a.jpg
# filtro aplicado./crack-2/test/images1616.rf.c868709931a671796794fdbb95352c5a.jpg
# ./crack-2/test/images/1675.rf.e3aa3f8d28d0247ef0284dd46dacc29f.jpg
# filtro aplicado./crack-2/test/images1675.rf.e3aa3f8d28d0247ef0284dd46dacc29f.jpg
# ./crack-2/test/images/1686.rf.809fb1b51c607e5cf787e44ef4ddd7b8.jpg
# filtro aplicado./crack-2/test/images1686.rf.809fb1b51c607e5cf787e44ef4ddd7b8.jpg
# ./crack-2/test/images/1706.rf.011d213c21ec78896c36728dcbc156f5.jpg
# filtro aplicado./crack-2/test/images1706.rf.011d213c21ec78896c36728dcbc156f5.jpg
# ./crack-2/test/images/1716.rf.85ea38b36008beaa72c5d8541f734eb0.jpg
# filtro aplicado./crack-2/test/images1716.rf.85ea38b36008beaa72c5d8541f734eb0.jpg
# ./crack-2/test/images/1722.rf.38b38f2e833309a4f35bfbf0432dffff.jpg
# filtro aplicado./crack-2/test/images1722.rf.38b38f2e833309a4f35bfbf0432dffff.jpg
# ./crack-2/test/images/1794.rf.7a03ca09d05e9e2941f768bc8570cb54.jpg
# ...

# %%
# run this at terminal %yolo train data= absolute_path\data.yaml model=yolov8n.pt epochs=10 lr0=0.01
# Out:
# UsageError: Line magic function `%yolo` not found.
